# %%
# import
import numpy as np
import pandas as pd
import os

# %%
def get_sample(df, n):
    '''
        df: Inp - Pass the dataframe df
        n : Inp - Fraction of data
        df_sample : Out - dataframe with n% of data df
    '''
    df_sample = df.sample(frac=n)
    return df_sample

# %%
print(os.getcwd())
df = pd.read_csv("../../../datasets/housing/housing.csv")
# Out:
# D:\Git\DeepLearning\fast.ai\meLearning

# %%
df1 = get_sample(df, .05)
print(df.size)
print(df1.size)
# Out:
# 206400
# 10320

# %%
def rem_col_null(df, p):
    '''
    Remove the Columns which is having more than
    p% NUll in it
    
    df: Inp - Input DataFrame
    p : Inp - Percentage, , 0.1 = 10%
    '''
    #return df[df.columns[list(df.isnull().sum()/df.size < p )]]
    return df.loc[:, df.isnull().sum()/df.size < p ]

# %%
def rem_row_null(df, p):
    '''
    Remove the Row which is having more than
    p% NUll in it
    
    df: Inp - Input DataFrame
    p : Inp - Percentage, 0.1 = 10%
    '''
    return df.loc[(df.isnull().transpose().sum()/df.size < p ).index]

# %%
def df_null(df):
    print("Null Check in DataFrame: \n")
    return df.isnull().sum()

# %%
def df_null_per(df):
    print("Null Check in DataFrame: \n")
    return df.isnull().sum().sort_index()/df.size

# %%
df1.size
# Out:
# 10320

# %%
df_null_per(df)
# Out:
# Null Check in DataFrame:
# households            0.000000
# housing_median_age    0.000000
# latitude              0.000000
# longitude             0.000000
# median_house_value    0.000000
# median_income         0.000000
# ocean_proximity       0.000000
# population            0.000000
# total_bedrooms        0.001003
# total_rooms           0.000000
# dtype: float64

# %%
list(df.isnull().sum()/df.size < 0.001)
# Out:
# [True, True, True, True, False, True, True, True, True, True]

# %%
df.loc[:, df.isnull().sum()/df.size < 0.0001 ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  population  \
# 0        -122.23     37.88                41.0        880.0       322.0
# 1        -122.22     37.86                21.0       7099.0      2401.0
# 2        -122.24     37.85                52.0       1467.0       496.0
# 3        -122.25     37.85                52.0       1274.0       558.0
# 4        -122.25     37.85                52.0       1627.0       565.0
# 5        -122.25     37.85                52.0        919.0       413.0
# 6        -122.25     37.84                52.0       2535.0      1094.0
# 7        -122.25     37.84                52.0       3104.0      1157.0
# 8        -122.26     37.84                42.0       2555.0      1206.0
# 9        -122.25     37.84                52.0       3549.0      1551.0
# 10       -122.26     37.85                52.0       2202.0       910.0
# 11       -122.26     37.85                52.0       3503.0      1504.0
# ...

# %%
# !source atulai.utils.py
# Out:
# 'source' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python atulai/utils.py

# %%
from atulai.utils import *

# %%
rmse(4,5)
# Out:
# 1.0

# %%
rmse(np.array([2,3]), np.array([4, 6]))
# Out:
# 2.5495097567963922

# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
X = df.drop('median_house_value', axis=1).values
y = df.median_house_value

# %%
X_train, X_test, y_train, y_test = split_vals(X, y, 0.2)
# Out:
# (16512, 9) (4128, 9) (16512,) (4128,)

# %%
n = len(X) - int(np.ceil(len(X)*0.2))
n
# Out:
# 16512

# %%
X_train, X_test = X[:n].copy(), X[n:].copy()

# %%
y_train, y_test = y[:n].copy(), y[n:].copy()
