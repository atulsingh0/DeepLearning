# %%
from keras.models import Model
from keras.layers import Input, Dense, Reshape, merge
from keras.layers.embeddings import Embedding
from keras.preprocessing.sequence import skipgrams
from keras.preprocessing import sequence

import urllib
import collections
import os
import zipfile

import numpy as np
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
def maybe_download(filename, url, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

# %%
def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
def collect_data(vocabulary_size=10000):
    url = 'http://mattmahoney.net/dc/'
    filename = maybe_download('text8.zip', url, 31344016)
    vocabulary = read_data(filename)
    print(vocabulary[:7])
    data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                                vocabulary_size)
    del vocabulary  # Hint to reduce memory.
    return data, count, dictionary, reverse_dictionary

# %%
vocab_size = 10000
data, count, dictionary, reverse_dictionary = collect_data(vocabulary_size=vocab_size)
print(data[:7])

window_size = 3
vector_dim = 300
epochs = 200000

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
sampling_table = sequence.make_sampling_table(vocab_size)
couples, labels = skipgrams(data, vocab_size, window_size=window_size, sampling_table=sampling_table)
word_target, word_context = zip(*couples)
word_target = np.array(word_target, dtype="int32")
word_context = np.array(word_context, dtype="int32")

print(couples[:10], labels[:10])
# Out:
# [[1166, 30], [2542, 177], [6152, 198], [4548, 26], [2651, 9], [8718, 930], [2974, 583], [285, 2226], [3930, 707], [4948, 393]] [1, 1, 1, 1, 1, 0, 0, 0, 1, 1]

# %%
# create some input variables
input_target = Input((1,))
input_context = Input((1,))

embedding = Embedding(vocab_size, vector_dim, input_length=1, name='embedding')
target = embedding(input_target)
target = Reshape((vector_dim, 1))(target)
context = embedding(input_context)
context = Reshape((vector_dim, 1))(context)

# %%
# setup a cosine similarity operation which will be output in a secondary model
similarity = merge([target, context], mode='cos', dot_axes=0)

# now perform the dot product operation to get a similarity measure
dot_product = merge([target, context], mode='dot', dot_axes=1)
dot_product = Reshape((1,))(dot_product)
# add the sigmoid output layer
output = Dense(1, activation='sigmoid')(dot_product)
# Out:
# /home/sanmati/anaconda3/envs/fastai2/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#
# /home/sanmati/anaconda3/envs/fastai2/lib/python3.6/site-packages/keras/legacy/layers.py:464: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# /home/sanmati/anaconda3/envs/fastai2/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   """

# %%
# create the primary training model
model = Model(input=[input_target, input_context], output=output)
model.compile(loss='binary_crossentropy', optimizer='rmsprop')
# Out:
# /home/sanmati/anaconda3/envs/fastai2/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`

# %%
# create a secondary validation model to run our similarity checks during training
validation_model = Model(input=[input_target, input_context], output=similarity)
# Out:
# /home/sanmati/anaconda3/envs/fastai2/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("me...)`

# %%
class SimilarityCallback:
    def run_sim(self):
        for i in range(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8  # number of nearest neighbors
            sim = self._get_sim(valid_examples[i])
            nearest = (-sim).argsort()[1:top_k + 1]
            log_str = 'Nearest to %s:' % valid_word
            for k in range(top_k):
                close_word = reverse_dictionary[nearest[k]]
                log_str = '%s %s,' % (log_str, close_word)
            print(log_str)

    @staticmethod
    def _get_sim(valid_word_idx):
        sim = np.zeros((vocab_size,))
        in_arr1 = np.zeros((1,))
        in_arr2 = np.zeros((1,))
        in_arr1[0,] = valid_word_idx
        for i in range(vocab_size):
            in_arr2[0,] = i
            out = validation_model.predict_on_batch([in_arr1, in_arr2])
            sim[i] = out
        return sim

# %%
sim_cb = SimilarityCallback()

arr_1 = np.zeros((1,))
arr_2 = np.zeros((1,))
arr_3 = np.zeros((1,))
for cnt in range(epochs):
    idx = np.random.randint(0, len(labels)-1)
    arr_1[0,] = word_target[idx]
    arr_2[0,] = word_context[idx]
    arr_3[0,] = labels[idx]
    loss = model.train_on_batch([arr_1, arr_2], arr_3)
    if cnt % 100 == 0:
        print("Iteration {}, loss={}".format(cnt, loss))
    if cnt % 10000 == 0:
        sim_cb.run_sim()
# Out:
# Iteration 0, loss=0.6474892497062683
# Nearest to system: lifted, cryptography, styles, gnu, operating, compatibility, remote, performance,
# Nearest to the: of, in, river, year, one, and, he, by,
# Nearest to or: ambiguous, industry, man, broadly, when, display, metropolis, draft,
# Nearest to of: the, one, in, unit, from, nd, topics, eight,
# Nearest to into: grows, peculiar, combination, months, boiling, falling, armenia, instruction,
# Nearest to between: easy, foster, nd, comparison, featured, creators, like, union,
# Nearest to state: dominant, do, nd, save, reaches, croatia, rhetoric, oregon,
# Nearest to see: canada, amber, brand, came, but, possibility, explosion, pushed,
# Nearest to were: arbitration, destroyed, goths, interference, reactor, committee, models, balkan,
# Nearest to is: program, fact, of, known, the, chromosome, miracle, one,
# Nearest to s: presidential, coke, who, boy, greek, to, appeal, malta,
# Nearest to when: inaccurate, sam, quasi, moment, or, a, can, circle,
# Nearest to was: by, student, ghost, oxford, leonard, provisional, castro, more,
# Nearest to to: employed, the, at, attached, eliminate, using, fight, effort,
# Nearest to united: kingdom, canada, everyone, jersey, netherlands, is, s, aviation,
# Nearest to d: edward, greenhouse, example, estonian, digital, gregory, regarding, archive,
# Iteration 100, loss=0.684705376625061
# Iteration 200, loss=0.7028079032897949
# Iteration 300, loss=0.6692691445350647
# Iteration 400, loss=0.6597340106964111
# Iteration 8000, loss=0.6579061150550842
# Iteration 8100, loss=0.7147852182388306
# Iteration 8200, loss=0.7219738364219666
# Iteration 8300, loss=0.7013460397720337
# Iteration 8400, loss=0.6890073418617249
# Iteration 8500, loss=0.6802024245262146
# Iteration 8600, loss=0.6681414842605591
# Iteration 8700, loss=0.7297948598861694
# Iteration 8800, loss=0.6707268357276917
# Iteration 8900, loss=0.6679899096488953
# Iteration 9000, loss=0.8225651979446411
# Iteration 9100, loss=0.6601633429527283
# Iteration 9200, loss=0.6985346078872681
# Iteration 9300, loss=0.6458507776260376
# Iteration 9400, loss=0.5904488563537598
# Iteration 9500, loss=0.8643513321876526
# Iteration 9600, loss=0.6876013278961182
# Iteration 9700, loss=0.6599335670471191
# Iteration 9800, loss=0.7324237823486328
# Iteration 9900, loss=0.6494957208633423
# Iteration 10000, loss=0.6534791588783264
# Nearest to system: rituals, styles, lifted, gnu, cryptography, compatibility, performance, centuries,
# Nearest to the: of, in, and, to, name, two, year, one,
# Nearest to or: angel, a, blame, man, thirty, democracy, ambiguous, essential,
# Nearest to of: the, one, in, and, is, to, two, eight,
# Nearest to into: breaks, peculiar, grows, enacted, falling, combination, instruction, subdivided,
# Nearest to between: easy, and, of, is, fe, gap, dublin, creators,
# Nearest to state: continue, dominant, texas, save, reaches, do, provision, croatia,
# Nearest to see: canada, educational, years, brand, amber, fashion, but, pushed,
# Nearest to were: destroyed, arbitration, reactor, interference, mid, created, fairly, goths,
# Nearest to is: the, of, to, one, this, fact, in, and,
# Nearest to s: to, the, boy, it, presidential, under, who, sound,
# Nearest to when: a, sam, small, inaccurate, quasi, moment, circle, talks,
# Nearest to was: by, more, the, student, oxford, working, tech, leonard,
# Nearest to to: the, of, and, as, boy, is, s, trying,
# Nearest to united: kingdom, canada, is, jersey, ii, everyone, netherlands, the,
# Nearest to d: greenhouse, b, edward, gregory, estonian, leibniz, rainfall, regarding,
# Iteration 10100, loss=0.6229771971702576
# Iteration 10200, loss=0.6458232402801514
# Iteration 10300, loss=0.5896826386451721
# Iteration 10400, loss=0.5837430357933044
# Iteration 10500, loss=0.652065634727478
# Iteration 10600, loss=0.6678570508956909
# Iteration 10700, loss=0.6329073905944824
# Iteration 10800, loss=0.6861175894737244
# Iteration 10900, loss=0.6511338949203491
# Iteration 11000, loss=0.64183109998703
# Iteration 11100, loss=0.8514115810394287
# Iteration 11200, loss=0.6991982460021973
# Iteration 11300, loss=0.6181951761245728
# Iteration 11400, loss=0.6318019032478333
# Iteration 11500, loss=0.744316816329956
# Iteration 11600, loss=0.7043030858039856
# Iteration 11700, loss=0.6555896997451782
# Iteration 11800, loss=0.6808788776397705
# Iteration 11900, loss=0.7169308662414551
# Iteration 12000, loss=0.6597237586975098
# Iteration 12100, loss=0.6569653749465942
# Iteration 12200, loss=0.38040149211883545
# Iteration 12300, loss=0.7199145555496216
# Iteration 12400, loss=0.6076105833053589
# Iteration 12500, loss=0.4874095916748047
# Iteration 12600, loss=0.89937424659729
# Iteration 12700, loss=0.7137709856033325
# Iteration 12800, loss=0.6543077230453491
# Iteration 12900, loss=0.7027794122695923
# Nearest to of: the, in, and, from, one, to, is, are,
# Nearest to into: months, peculiar, shah, grows, combination, market, boiling, breaks,
# Nearest to between: gap, and, of, is, the, to, in, union,
# Nearest to state: continue, dominant, texas, save, reaches, nd, chance, do,
# Nearest to see: also, educational, canada, given, moses, example, ren, amber,
# Nearest to were: destroyed, in, arbitration, the, interference, an, fairly, races,
# Nearest to is: the, of, in, and, to, one, a, program,
# Nearest to s: the, in, to, one, five, and, row, of,
# Nearest to when: a, small, sam, moment, quasi, food, alliance, inaccurate,
# Nearest to was: the, in, one, of, by, that, and, more,
# Nearest to to: the, and, as, of, a, is, in, from,
# Nearest to united: kingdom, ii, is, the, canada, senate, in, three,
# Nearest to d: edward, greenhouse, b, amino, regarding, gregory, leibniz, cricketer,
# Iteration 20100, loss=0.9268277287483215
# Iteration 20200, loss=0.6180893182754517
# Iteration 20300, loss=0.6170247793197632
# Iteration 20400, loss=0.6145671606063843
# Iteration 20500, loss=0.6390989422798157
# Iteration 20600, loss=0.7296448945999146
# Iteration 20700, loss=0.5519221425056458
# Iteration 20800, loss=0.827825665473938
# Iteration 20900, loss=0.6199060678482056
# Iteration 21000, loss=0.807340681552887
# Iteration 21100, loss=0.5594544410705566
# Iteration 21200, loss=0.8594117164611816
# Iteration 21300, loss=0.6767793297767639
# Iteration 21400, loss=0.5484141707420349
# Iteration 21500, loss=1.017127513885498
# Iteration 21600, loss=0.6026651859283447
# Iteration 21700, loss=0.6947582364082336
# Iteration 21800, loss=0.6475757360458374
# Iteration 21900, loss=0.7432327270507812
# Iteration 22000, loss=0.7425000667572021
# Iteration 22100, loss=0.6343662142753601
# Iteration 22200, loss=0.41478389501571655
# Iteration 22300, loss=0.656480610370636
# Iteration 22400, loss=0.6891886591911316
# Iteration 22500, loss=0.6574355363845825
# Iteration 22600, loss=0.7096281051635742
# Iteration 22700, loss=0.7167961597442627
# Iteration 22800, loss=0.6619046926498413
# Iteration 22900, loss=0.7239300608634949
# Iteration 23000, loss=0.5400652289390564
# Iteration 23100, loss=0.625994086265564
# Iteration 23200, loss=0.7361547350883484
# Iteration 23300, loss=0.6200580596923828
# Iteration 23400, loss=0.6318682432174683
# Iteration 23500, loss=1.1636857986450195
# Iteration 23600, loss=0.3437826633453369
# Iteration 23700, loss=0.7687020301818848
# Iteration 23800, loss=0.7728082537651062
# Iteration 23900, loss=0.09036391228437424
# Iteration 24000, loss=0.754933774471283
# Iteration 24100, loss=0.5777796506881714
# Iteration 24200, loss=0.7361129522323608
# Iteration 24300, loss=0.8744702935218811
# Iteration 24400, loss=0.5647087693214417
# Iteration 24500, loss=0.6794118285179138
# Iteration 24600, loss=0.6891584992408752
# Iteration 24700, loss=0.655949056148529
# Iteration 24800, loss=0.6826522946357727
# Iteration 24900, loss=0.667766809463501
# Iteration 25000, loss=0.6941556334495544
# Iteration 25100, loss=0.49991604685783386
# Iteration 25200, loss=0.38081714510917664
# Iteration 25300, loss=0.7079938054084778
# Iteration 25400, loss=0.7094134092330933
# Iteration 25500, loss=0.6457250118255615
# Iteration 25600, loss=0.7407634854316711
# Iteration 25700, loss=0.6904887557029724
# Iteration 25800, loss=0.7427176237106323
# Iteration 25900, loss=0.6812946200370789
# Iteration 26000, loss=0.7439080476760864
# Iteration 26100, loss=0.6059244275093079
# Iteration 26200, loss=0.7051720023155212
# Iteration 26300, loss=0.6851903200149536
# Iteration 26400, loss=0.648169219493866
# Iteration 26500, loss=0.6579064726829529
# Iteration 26600, loss=0.6766733527183533
# Iteration 26700, loss=0.02154700644314289
# Iteration 26800, loss=0.6282420754432678
# Iteration 26900, loss=0.6698745489120483
# Iteration 27000, loss=0.7201276421546936
# Iteration 27100, loss=0.8030025959014893
# Iteration 27200, loss=0.6545121669769287
# Iteration 27300, loss=0.7016364336013794
# Iteration 27400, loss=0.745599627494812
# Iteration 27500, loss=0.7256552577018738
# Iteration 27600, loss=0.5961118936538696
# Iteration 27700, loss=0.7765123248100281
# Iteration 27800, loss=0.6804406046867371
# Iteration 27900, loss=0.24195435643196106
# Iteration 28000, loss=0.14259518682956696
# Iteration 28100, loss=0.6689159870147705
# Iteration 28200, loss=0.7700046300888062
# Iteration 28300, loss=0.6597834229469299
# Iteration 28400, loss=0.7629785537719727
# Iteration 28500, loss=0.7220881581306458
# Iteration 28600, loss=0.5735523104667664
# Iteration 28700, loss=0.6383160948753357
# Iteration 28800, loss=0.6462448835372925
# Iteration 28900, loss=0.6431427001953125
# Iteration 29000, loss=0.7159937024116516
# Iteration 29100, loss=0.26413753628730774
# Iteration 29200, loss=0.6882470846176147
# Iteration 29300, loss=0.7162457704544067
# Iteration 29400, loss=0.7139139175415039
# Iteration 29500, loss=0.7331297993659973
# Iteration 29600, loss=0.6327378153800964
# Iteration 29700, loss=0.6920819878578186
# Iteration 29800, loss=0.5775467753410339
# Iteration 29900, loss=0.6397353410720825
# Iteration 30000, loss=0.6352519989013672
# Nearest to system: operating, styles, used, legal, centuries, compatibility, the, earth,
# Nearest to the: of, in, and, to, is, a, one, as,
# Nearest to or: the, a, in, it, and, of, is, also,
# Nearest to of: the, and, in, to, is, from, one, a,
# Nearest to into: the, months, to, market, opponents, combination, age, shah,
# Nearest to between: gap, and, to, is, union, history, railway, has,
# Nearest to state: continue, nd, dominant, pseudonym, reaches, roosevelt, do, rhetoric,
# Nearest to see: also, international, example, educational, canada, regional, walk, the,
# Nearest to were: destroyed, the, in, that, first, and, is, of,
# Nearest to is: the, of, in, and, a, to, one, it,
# Nearest to s: the, and, to, in, five, from, of, one,
# Nearest to when: a, small, the, are, moment, being, party, priests,
# Nearest to was: the, that, of, in, and, by, a, one,
# Nearest to to: the, and, of, as, a, in, an, is,
# Nearest to united: kingdom, ii, is, in, the, of, and, three,
# Nearest to d: edward, greenhouse, b, amino, four, cricketer, regarding, greek,
# Iteration 30100, loss=0.6579462289810181
# Iteration 30200, loss=0.6846668720245361
# Iteration 30300, loss=0.7026621699333191
# Iteration 30400, loss=0.7911361455917358
# Iteration 30500, loss=0.7698862552642822
# Iteration 30600, loss=0.6065016984939575
# Iteration 30700, loss=0.5807173848152161
# Iteration 30800, loss=0.8814879655838013
# Iteration 30900, loss=0.6933456063270569
# Iteration 38500, loss=0.8128222227096558
# Iteration 38600, loss=0.6011903285980225
# Iteration 38700, loss=0.485377699136734
# Iteration 38800, loss=0.38657665252685547
# Iteration 38900, loss=0.5989391803741455
# Iteration 39000, loss=0.6004642248153687
# Iteration 39100, loss=0.6610158085823059
# Iteration 39200, loss=0.7853193283081055
# Iteration 39300, loss=0.8050649166107178
# Iteration 39400, loss=0.8355191946029663
# Iteration 39500, loss=0.5991619229316711
# Iteration 39600, loss=0.6257668733596802
# Iteration 39700, loss=0.40886786580085754
# Iteration 39800, loss=0.6497001647949219
# Iteration 39900, loss=0.5330071449279785
# Iteration 40000, loss=0.9054309129714966
# Nearest to system: the, and, to, operating, of, that, in, a,
# Nearest to the: of, and, in, to, a, is, that, as,
# Nearest to or: the, a, in, and, of, is, that, it,
# Nearest to of: the, and, in, to, from, is, a, that,
# Nearest to into: the, to, of, a, as, is, months, commissioned,
# Nearest to between: gap, and, to, is, has, union, in, of,
# Nearest to state: nd, in, continue, the, and, of, is, from,
# Nearest to see: also, to, the, year, that, of, in, example,
# Nearest to were: the, destroyed, in, that, and, notably, first, is,
# Nearest to is: the, of, in, and, a, to, it, one,
# Nearest to s: the, from, and, in, to, of, nine, one,
# Nearest to when: a, the, being, this, to, of, in, war,
# Nearest to was: the, that, in, of, and, by, a, to,
# Nearest to to: the, and, of, a, in, as, an, from,
# Nearest to united: kingdom, in, ii, is, the, of, from, and,
# Nearest to d: greenhouse, edward, four, b, amino, cricketer, amos, archive,
# Iteration 40100, loss=0.8861773610115051
# Iteration 40200, loss=0.5404752492904663
# Iteration 40300, loss=0.6538198590278625
# Iteration 40400, loss=0.6995185613632202
# Iteration 40500, loss=0.6371943354606628
# Iteration 40600, loss=0.6219000816345215
# Iteration 40700, loss=0.6650948524475098
# Iteration 40800, loss=0.5869726538658142
# Iteration 40900, loss=0.6064648032188416
# Iteration 41000, loss=0.817392110824585
# Iteration 41100, loss=0.5311128497123718
# Iteration 41200, loss=0.6797855496406555
# Iteration 41300, loss=0.8365733623504639
# Iteration 41400, loss=0.9434702396392822
# Iteration 41500, loss=0.7292239665985107
# Iteration 41600, loss=1.1342132091522217
# Iteration 41700, loss=0.8135205507278442
# Iteration 41800, loss=0.6076961755752563
# Iteration 41900, loss=0.8602232933044434
# Iteration 42000, loss=0.8009074330329895
# Iteration 42100, loss=0.7877737283706665
# Iteration 42200, loss=0.5964677929878235
# Iteration 42300, loss=0.6609700918197632
# Iteration 42400, loss=0.9466252326965332
# Iteration 42500, loss=0.49061381816864014
# Iteration 42600, loss=0.6159127950668335
# Iteration 42700, loss=0.581595778465271
# Iteration 42800, loss=0.23019416630268097
# Iteration 42900, loss=0.36568042635917664
# Iteration 43000, loss=0.5938860774040222
# Iteration 43100, loss=0.6353431344032288
# Iteration 43200, loss=0.6713486313819885
# Iteration 43300, loss=0.5989730954170227
# Iteration 43400, loss=0.5759608149528503
# Iteration 43500, loss=0.8237890005111694
# Iteration 43600, loss=0.5346662402153015
# Iteration 43700, loss=0.7319644689559937
# Iteration 43800, loss=0.31915950775146484
# Iteration 56900, loss=0.565925657749176
# Iteration 57000, loss=0.0008223455515690148
# Iteration 57100, loss=0.22519782185554504
# Iteration 57200, loss=0.6992058753967285
# Iteration 57300, loss=0.5349910259246826
# Iteration 57400, loss=0.5103022456169128
# Iteration 57500, loss=0.8819458484649658
# Iteration 57600, loss=0.6123796105384827
# Iteration 57700, loss=0.8464158773422241
# Iteration 57800, loss=0.5284155607223511
# Iteration 57900, loss=0.6600985527038574
# Iteration 58000, loss=0.8915416598320007
# Iteration 58100, loss=1.0792605876922607
# Iteration 58200, loss=0.8607499599456787
# Iteration 58300, loss=0.6052719950675964
# Iteration 58400, loss=0.5398131608963013
# Iteration 58500, loss=0.5060733556747437
# Iteration 58600, loss=0.7528322339057922
# Iteration 58700, loss=0.524734377861023
# Iteration 58800, loss=0.8448101282119751
# Iteration 58900, loss=0.6765446662902832
# Iteration 59000, loss=0.5931251049041748
# Iteration 59100, loss=0.9730801582336426
# Iteration 59200, loss=0.4995782971382141
# Iteration 59300, loss=0.5474891662597656
# Iteration 59400, loss=0.6959223747253418
# Iteration 59500, loss=0.6709873080253601
# Iteration 59600, loss=0.8966353535652161
# Iteration 59700, loss=0.0033412298653274775
# Iteration 59800, loss=0.2581787109375
# Iteration 59900, loss=0.43726828694343567
# Iteration 60000, loss=0.4776747226715088
# Nearest to system: the, in, other, to, and, of, a, that,
# Nearest to the: of, in, and, to, a, that, is, as,
# Nearest to or: the, a, and, that, of, in, to, as,
# Nearest to of: the, and, in, to, a, is, from, that,
# Nearest to into: the, a, of, to, its, is, as, from,
# Nearest to between: and, to, is, in, of, has, a, the,
# Nearest to state: the, and, to, of, in, two, people, for,
# Nearest to see: also, to, the, that, and, of, in, two,
# Nearest to were: the, that, in, and, are, is, of, to,
# Nearest to is: the, of, in, and, it, to, a, that,
# Nearest to s: the, in, and, to, of, a, nine, one,
# Nearest to when: a, the, was, party, as, and, being, that,
# Nearest to was: the, that, in, of, a, to, and, is,
# Nearest to to: the, of, in, and, a, as, is, an,
# Nearest to united: kingdom, states, in, is, ii, the, of, from,
# Nearest to d: greenhouse, edward, seven, player, descent, four, five, two,
# Iteration 60100, loss=0.49360930919647217
# Iteration 60200, loss=1.8537077903747559
# Iteration 60300, loss=0.42363861203193665
# Iteration 60400, loss=0.6600599884986877
# Iteration 60500, loss=0.8486731648445129
# Iteration 60600, loss=0.7165813446044922
# Iteration 60700, loss=0.5803869962692261
# Iteration 60800, loss=0.6578528881072998
# Iteration 60900, loss=0.6839940547943115
# Iteration 61000, loss=0.5472315549850464
# Iteration 61100, loss=0.5358421802520752
# Iteration 61200, loss=0.4586712121963501
# Iteration 61300, loss=0.6262680292129517
# Iteration 61400, loss=0.659032940864563
# Iteration 61500, loss=0.8276073932647705
# Iteration 61600, loss=0.8542237281799316
# Iteration 61700, loss=0.00032644826569594443
# Iteration 61800, loss=0.9285231828689575
# Iteration 61900, loss=0.23201386630535126
# Iteration 62000, loss=0.743354856967926
# Iteration 62100, loss=0.49464312195777893
# Iteration 62200, loss=0.8293118476867676
# Iteration 62300, loss=0.006261239759624004
# Iteration 69800, loss=0.39966219663619995
# Iteration 69900, loss=1.0445505380630493
# Iteration 70000, loss=0.5985676646232605
# Nearest to system: the, to, in, and, a, other, of, that,
# Nearest to the: of, in, and, to, a, is, that, as,
# Nearest to or: and, a, the, of, in, that, as, to,
# Nearest to of: the, and, in, a, to, is, from, that,
# Nearest to into: the, a, of, to, and, as, from, is,
# Nearest to between: and, to, in, a, is, of, the, has,
# Nearest to state: the, two, of, and, for, in, people, from,
# Nearest to see: also, the, to, that, of, in, and, two,
# Nearest to were: the, in, and, are, is, of, that, to,
# Nearest to is: the, of, in, and, to, a, it, as,
# Nearest to s: the, in, of, and, to, a, it, from,
# Nearest to when: a, the, was, as, or, and, that, of,
# Nearest to was: the, in, of, that, a, and, to, is,
# Nearest to to: the, of, in, and, a, is, as, that,
# Nearest to united: kingdom, states, in, the, is, of, ii, from,
# Nearest to d: french, four, from, seven, edward, greenhouse, b, one,
# Iteration 70100, loss=0.460712730884552
# Iteration 70200, loss=0.6918346881866455
# Iteration 70300, loss=0.5493916869163513
# Iteration 70400, loss=0.6243813037872314
# Iteration 70500, loss=0.5653811097145081
# Iteration 70600, loss=0.9418083429336548
# Iteration 70700, loss=0.6103147864341736
# Iteration 70800, loss=0.19635295867919922
# Iteration 70900, loss=0.6370022892951965
# Iteration 71000, loss=0.4990173578262329
# Iteration 71100, loss=7.152557373046875e-07
# Iteration 71200, loss=0.5394411683082581
# Iteration 71300, loss=0.5631744265556335
# Iteration 71400, loss=0.5241857171058655
# Iteration 71500, loss=0.28677910566329956
# Iteration 71600, loss=1.0477714538574219
# Iteration 71700, loss=0.8340632319450378
# Iteration 71800, loss=2.431898974464275e-05
# Iteration 71900, loss=0.5926188230514526
# Iteration 72000, loss=0.4134421646595001
# Iteration 72100, loss=0.3859161138534546
# Iteration 72200, loss=1.192093321833454e-07
# Iteration 72300, loss=0.5582656860351562
# Iteration 72400, loss=0.9397165179252625
# Iteration 72500, loss=0.5080887079238892
# Iteration 72600, loss=0.40001922845840454
# Iteration 72700, loss=0.4751291871070862
# Iteration 72800, loss=0.5095540285110474
# Iteration 72900, loss=0.5084884762763977
# Iteration 73000, loss=0.5412696599960327
# Iteration 73100, loss=0.4076080024242401
# Iteration 73200, loss=0.4655040204524994
# Iteration 73300, loss=0.0013704146258533
# Iteration 73400, loss=0.02223934791982174
# Iteration 73500, loss=1.0174219608306885
# Iteration 73600, loss=0.4766068458557129
# Iteration 73700, loss=0.13332821428775787
# Iteration 73800, loss=0.5462528467178345
# Iteration 73900, loss=0.022191444411873817
# Iteration 74000, loss=0.10459081083536148
# Iteration 74100, loss=0.4449412226676941
# Iteration 74200, loss=0.5453189015388489
# Iteration 74300, loss=0.9392825365066528
# Iteration 74400, loss=0.8787297010421753
# Iteration 74500, loss=0.3968712091445923
# Iteration 74600, loss=0.7918457388877869
# Iteration 74700, loss=0.9060494899749756
# Iteration 74800, loss=0.8414530158042908
# Iteration 74900, loss=0.1254805624485016
# Iteration 75000, loss=0.6070690155029297
# Iteration 75100, loss=0.2264755368232727
# Iteration 75200, loss=0.9026207327842712
# Iteration 75300, loss=0.4375511407852173
# Iteration 75400, loss=0.9891513586044312
# Iteration 75500, loss=0.524029552936554
# Iteration 75600, loss=0.47987908124923706
# Iteration 75700, loss=0.5700334906578064
# Iteration 75800, loss=0.325947642326355
# Iteration 75900, loss=0.012285890057682991
# Iteration 76000, loss=0.5678528547286987
# Iteration 76100, loss=1.0545368194580078
# Iteration 76200, loss=0.7124307751655579
# Iteration 76300, loss=0.779604434967041
# Iteration 76400, loss=0.026571180671453476
# Iteration 76500, loss=0.526085376739502
# Iteration 76600, loss=0.4307088255882263
# Iteration 76700, loss=0.6603242754936218
# Iteration 76800, loss=3.4059314727783203
# Iteration 76900, loss=0.8853594064712524
# Iteration 77000, loss=0.42775896191596985
# Iteration 77100, loss=0.19755473732948303
# Iteration 77200, loss=0.6313874125480652
# Iteration 77300, loss=0.5708543062210083
# Iteration 77400, loss=0.410556435585022
# Iteration 77500, loss=0.6115242838859558
# Iteration 77600, loss=0.0006184105877764523
# Iteration 77700, loss=0.8290315270423889
# Iteration 77800, loss=0.5543540716171265
# Iteration 77900, loss=0.40718820691108704
# Iteration 78000, loss=0.522742509841919
# Iteration 78100, loss=0.6228841543197632
# Iteration 78200, loss=1.1834769248962402
# Iteration 78300, loss=0.541763186454773
# Iteration 78400, loss=0.7790811061859131
# Iteration 78500, loss=0.5043964982032776
# Iteration 78600, loss=0.7012968063354492
# Iteration 78700, loss=0.43573927879333496
# Iteration 78800, loss=0.33827903866767883
# Iteration 78900, loss=0.5689072012901306
# Iteration 79000, loss=0.6896809339523315
# Iteration 79100, loss=2.611478567123413
# Iteration 79200, loss=4.968580722808838
# Iteration 79300, loss=0.762518048286438
# Iteration 79400, loss=1.192093321833454e-07
# Iteration 79500, loss=0.7344962358474731
# Iteration 79600, loss=0.5103082656860352
# Iteration 79700, loss=0.5059131383895874
# Iteration 79800, loss=0.6218615770339966
# Iteration 79900, loss=0.002335531637072563
# Iteration 80000, loss=0.36421191692352295
# Nearest to system: the, in, to, a, and, other, of, is,
# Nearest to the: in, of, and, to, a, is, that, as,
# Nearest to or: a, the, in, of, and, that, as, to,
# Nearest to of: the, and, in, a, to, is, from, that,
# Nearest to into: the, a, to, of, in, as, is, from,
# Nearest to between: and, to, a, in, is, of, the, as,
# Nearest to state: of, and, the, in, two, to, from, one,
# Nearest to see: also, the, in, that, to, of, and, two,
# Nearest to were: the, are, and, in, be, to, is, that,
# Nearest to is: the, of, in, and, it, a, to, as,
# Nearest to s: the, in, to, of, and, a, it, one,
# Nearest to when: a, the, that, and, as, or, was, in,
# Nearest to was: the, in, that, of, a, and, to, is,
# Nearest to to: the, in, of, and, a, is, as, that,
# Nearest to united: kingdom, states, in, is, the, of, from, ii,
# Nearest to d: seven, four, one, two, three, five, zero, j,
# Iteration 80100, loss=2.9363515377044678
# Iteration 80200, loss=1.0611534118652344
# Iteration 80300, loss=0.6537063121795654
# Iteration 80400, loss=0.49461251497268677
# Iteration 80500, loss=0.44540390372276306
# Iteration 80600, loss=0.5948930382728577
# Iteration 80700, loss=0.4441317319869995
# Iteration 80800, loss=1.5739856958389282
# Iteration 88300, loss=0.42468440532684326
# Iteration 88400, loss=0.43864697217941284
# Iteration 88500, loss=1.2196464538574219
# Iteration 88600, loss=0.08589604496955872
# Iteration 88700, loss=0.18288780748844147
# Iteration 88800, loss=0.8002185821533203
# Iteration 88900, loss=0.316276490688324
# Iteration 89000, loss=0.8316839933395386
# Iteration 89100, loss=0.6227976679801941
# Iteration 89200, loss=0.8280006647109985
# Iteration 89300, loss=0.3758796155452728
# Iteration 89400, loss=0.7958289384841919
# Iteration 89500, loss=0.8961802124977112
# Iteration 89600, loss=0.5543463826179504
# Iteration 89700, loss=0.565616250038147
# Iteration 89800, loss=1.1112314462661743
# Iteration 89900, loss=0.5682684183120728
# Iteration 90000, loss=0.3970591425895691
# Nearest to system: the, in, to, and, a, of, is, that,
# Nearest to the: in, of, and, a, to, is, that, was,
# Nearest to or: a, the, and, in, as, of, that, to,
# Nearest to of: the, and, in, a, to, is, from, that,
# Nearest to into: the, a, of, to, in, is, as, and,
# Nearest to between: and, in, to, of, is, a, the, as,
# Nearest to state: of, the, and, in, for, two, from, to,
# Nearest to see: also, the, in, to, that, and, of, on,
# Nearest to were: the, and, be, to, is, in, are, that,
# Nearest to is: the, in, of, a, and, to, it, as,
# Nearest to s: the, in, to, of, and, a, it, one,
# Nearest to when: a, the, that, or, was, and, as, is,
# Nearest to was: the, in, that, of, a, and, is, to,
# Nearest to to: the, and, of, in, a, is, as, that,
# Nearest to united: states, kingdom, in, the, is, of, from, to,
# Nearest to d: four, seven, french, one, two, five, three, zero,
# Iteration 90100, loss=0.500831127166748
# Iteration 90200, loss=0.8122326135635376
# Iteration 90300, loss=0.4754464030265808
# Iteration 90400, loss=0.7860671877861023
# Iteration 90500, loss=0.4062051773071289
# Iteration 90600, loss=0.5719373226165771
# Iteration 90700, loss=0.9227362871170044
# Iteration 90800, loss=0.28784069418907166
# Iteration 90900, loss=0.40415892004966736
# Iteration 91000, loss=0.3489338755607605
# Iteration 91100, loss=0.5970696806907654
# Iteration 91200, loss=0.5143291354179382
# Iteration 91300, loss=0.42338961362838745
# Iteration 91400, loss=0.4808605909347534
# Iteration 91500, loss=0.3141593337059021
# Iteration 91600, loss=4.264822483062744
# Iteration 91700, loss=0.511317253112793
# Iteration 91800, loss=0.3158344626426697
# Iteration 91900, loss=0.9850373268127441
# Iteration 92000, loss=0.4844134449958801
# Iteration 92100, loss=0.3957931399345398
# Iteration 92200, loss=0.1794622242450714
# Iteration 92300, loss=1.192093321833454e-07
# Iteration 92400, loss=0.9357888698577881
# Iteration 92500, loss=0.32615822553634644
# Iteration 92600, loss=0.6427251696586609
# Iteration 92700, loss=0.4668882191181183
# Iteration 92800, loss=0.5145593285560608
# Iteration 92900, loss=1.192093321833454e-07
# Iteration 93000, loss=0.9952470064163208
# ...
# Iteration 168500, loss=0.2894604802131653
# Iteration 168600, loss=0.0001696491672191769
# Iteration 168700, loss=0.33283868432044983
# Iteration 168800, loss=1.3523311614990234
# Iteration 168900, loss=3.1014130115509033
# Iteration 169000, loss=1.1032272577285767
# Iteration 169100, loss=0.3606378734111786
# Iteration 169200, loss=1.0442225933074951
# Iteration 169300, loss=8.063093185424805
# Iteration 169400, loss=0.8584978580474854
# Iteration 169500, loss=0.3003912568092346
# Iteration 169600, loss=1.192093321833454e-07
# Iteration 169700, loss=0.34337177872657776
# Iteration 169800, loss=0.38693445920944214
# Iteration 169900, loss=0.002992094960063696
# Iteration 170000, loss=2.1293318271636963
# Nearest to system: a, in, that, and, to, the, as, not,
# Nearest to the: in, and, of, as, a, was, that, to,
# Nearest to or: a, as, is, the, that, in, and, was,
# Nearest to of: the, in, and, as, is, a, that, was,
# Nearest to into: a, to, as, from, the, by, is, of,
# Nearest to between: in, is, and, the, a, it, of, as,
# Nearest to state: in, of, as, from, for, and, s, was,
# Nearest to see: also, that, the, for, s, on, and, in,
# Nearest to were: the, be, and, are, by, that, of, a,
# Nearest to is: of, as, the, in, a, and, to, it,
# Nearest to s: the, in, of, as, that, and, by, a,
# Nearest to when: a, the, was, and, as, an, that, not,
# Nearest to was: the, a, and, of, that, by, in, as,
# Nearest to to: as, the, a, and, in, is, was, of,
# Nearest to united: in, states, the, of, is, kingdom, from, and,
# Nearest to d: one, two, seven, four, five, nine, three, zero,
# Iteration 170100, loss=0.33925601840019226
# Iteration 170200, loss=0.4565514922142029
# Iteration 170300, loss=1.1088372468948364
# Iteration 170400, loss=0.3258240818977356
# Iteration 170500, loss=0.9184443950653076
# Iteration 170600, loss=1.190969467163086
# Iteration 170700, loss=0.4185764193534851
# Iteration 170800, loss=0.7081965208053589
# Iteration 170900, loss=1.25747549533844
# Iteration 171000, loss=0.46334099769592285
# Iteration 171100, loss=1.192093321833454e-07
# Iteration 171200, loss=1.192093321833454e-07
# Iteration 171300, loss=0.7433691620826721
# Iteration 171400, loss=3.3012311458587646
# Iteration 171500, loss=1.1193087100982666
# Iteration 171600, loss=0.24555329978466034
# Iteration 171700, loss=1.1369719505310059
# Iteration 171800, loss=0.6949878931045532
# Iteration 171900, loss=0.3740711808204651
# Iteration 172000, loss=0.5738415122032166
# Iteration 172100, loss=1.192093321833454e-07
# Iteration 172200, loss=0.36295270919799805
# Iteration 172300, loss=0.31683847308158875
# Iteration 172400, loss=0.35818570852279663
# Iteration 172500, loss=0.2875922620296478
# Iteration 172600, loss=1.2840540409088135
# Iteration 172700, loss=0.3584350645542145
# Iteration 172800, loss=0.0013033889699727297
# Iteration 172900, loss=0.2926865220069885
# Iteration 173000, loss=1.192093321833454e-07
# Iteration 173100, loss=0.7324931621551514
# Iteration 173200, loss=0.0018541105091571808
# Iteration 173300, loss=0.10454653948545456
# Iteration 173400, loss=0.43207067251205444
# Iteration 173500, loss=0.25128817558288574
# Iteration 173600, loss=0.6487843990325928
# Iteration 173700, loss=0.4157865047454834
# Iteration 173800, loss=0.40648573637008667
# Iteration 173900, loss=0.015556065365672112
# Iteration 174000, loss=4.502848148345947
# Iteration 174100, loss=0.0009090261301025748
# Iteration 174200, loss=0.600995659828186
# Iteration 174300, loss=0.5008252859115601
# Iteration 174400, loss=0.4022299349308014
# Iteration 174500, loss=0.32237178087234497
# Iteration 174600, loss=0.3606840968132019
# Iteration 187600, loss=0.2774930000305176
# Iteration 187700, loss=4.363966941833496
# Iteration 187800, loss=1.4206759929656982
# Iteration 187900, loss=0.06596071273088455
# Iteration 188000, loss=0.3864356279373169
# Iteration 188100, loss=0.8918881416320801
# Iteration 188200, loss=3.373680010554381e-05
# Iteration 188300, loss=1.192093321833454e-07
# Iteration 188400, loss=1.1639472246170044
# Iteration 188500, loss=0.5286621451377869
# Iteration 188600, loss=1.5497333151870407e-05
# Iteration 188700, loss=0.3529830276966095
# Iteration 188800, loss=0.02253156155347824
# Iteration 188900, loss=0.2967682182788849
# Iteration 189000, loss=1.9431299733696505e-05
# Iteration 189100, loss=0.49436503648757935
# Iteration 189200, loss=0.4930447041988373
# Iteration 189300, loss=1.1837886571884155
# Iteration 189400, loss=0.3151441216468811
# Iteration 189500, loss=0.37766721844673157
# Iteration 189600, loss=1.192093321833454e-07
# Iteration 189700, loss=0.041535478085279465
# Iteration 189800, loss=0.3091450333595276
# Iteration 189900, loss=1.2871880531311035
# Iteration 190000, loss=0.7631574869155884
# Nearest to system: a, in, as, and, the, not, that, to,
# Nearest to the: in, and, of, was, a, as, that, for,
# Nearest to or: as, a, is, on, in, was, and, the,
# Nearest to of: the, and, in, is, was, as, a, from,
# Nearest to into: a, as, from, to, the, by, is, was,
# Nearest to between: and, in, is, a, the, it, as, of,
# Nearest to state: in, of, as, for, from, was, and, the,
# Nearest to see: also, that, for, s, on, the, in, was,
# Nearest to were: be, the, and, by, not, a, that, is,
# Nearest to is: of, in, as, the, a, and, it, was,
# Nearest to s: the, in, of, that, and, as, by, from,
# Nearest to when: a, was, the, and, that, for, not, is,
# Nearest to was: the, a, and, that, by, of, as, in,
# Nearest to to: as, the, a, and, in, was, is, by,
# Nearest to united: states, in, the, from, kingdom, of, is, to,
# Nearest to d: one, four, two, seven, three, nine, five, zero,
# Iteration 190100, loss=1.3802378177642822
# Iteration 190200, loss=0.6677157878875732
# Iteration 190300, loss=1.372516393661499
# Iteration 190400, loss=0.3367689847946167
# Iteration 190500, loss=2.6791605949401855
# Iteration 190600, loss=1.192093321833454e-07
# Iteration 190700, loss=0.452920138835907
# Iteration 190800, loss=0.5720617175102234
# Iteration 190900, loss=0.08480546623468399
# Iteration 191000, loss=0.43393945693969727
# Iteration 191100, loss=0.5011829137802124
# Iteration 191200, loss=0.5416353940963745
# Iteration 191300, loss=0.3227136433124542
# Iteration 191400, loss=1.1552462577819824
# Iteration 191500, loss=0.3381965756416321
# Iteration 191600, loss=0.6338499188423157
# Iteration 191700, loss=1.192093321833454e-07
# Iteration 191800, loss=0.3563862442970276
# Iteration 191900, loss=0.43440791964530945
# Iteration 192000, loss=0.4444803297519684
# Iteration 192100, loss=0.3793412744998932
# Iteration 192200, loss=2.0027357095386833e-05
# Iteration 192300, loss=0.30518126487731934
# Iteration 192400, loss=0.17899754643440247
# Iteration 192500, loss=0.8005361557006836
# Iteration 192600, loss=0.9752603769302368
# Iteration 192700, loss=0.5113961696624756
# Iteration 192800, loss=0.42202579975128174
# Iteration 192900, loss=0.37768879532814026
